// %% [markdown]
// <h1 style="color:DodgerBlue">Управление зависимостями </h1>

// %% [markdown]
// ### Интерфейсы в C#
//
// **Интерфейс** — это контракт, который определяет набор методов и свойств, которые класс должен реализовать. Интерфейсы позволяют создать гибкую и расширяемую архитектуру, поскольку они отделяют определение поведения от его реализации.
//
// Давайте подробно разберем понятия интерфейсов и управления зависимостями в C# на примере классов `Vehicle`, `Car` и `Motorcycle`.
//
// #### Пример интерфейса
//
// Предположим, мы имеем интерфейс `IVehicle`, который определяет поведение транспортных средств. Ниже приведен пример его определения:
//
// ```csharp
// public interface IVehicle
// {
//     void Start();            // Метод для запуска транспортного средства
//     void Stop();             // Метод для остановки транспортного средства
//     int GetNumberOfWheels(); // Метод для получения количества колес
// }
// ```
//
// Интерфейс `IVehicle` требует, чтобы любой класс, реализующий его, обеспечил реализацию этих методов.
//
// ### Реализация интерфейса
//
// Теперь создадим классы `Car` и `Motorcycle`, которые будут реализовывать этот интерфейс:
//
// ```csharp
// public class Car : IVehicle
// {
//     public void Start()
//     {
//         Console.WriteLine("Машина запущена.");
//     }
//
//     public void Stop()
//     {
//         Console.WriteLine("Машина остановлена.");
//     }
//
//     public int GetNumberOfWheels()
//     {
//         return 4; // У машины 4 колеса
//     }
// }
//
// public class Motorcycle : IVehicle
// {
//     public void Start()
//     {
//         Console.WriteLine("Мотоцикл запущен.");
//     }
//
//     public void Stop()
//     {
//         Console.WriteLine("Мотоцикл остановлен.");
//     }
//
//     public int GetNumberOfWheels()
//     {
//         return 2; // У мотоцикла 2 колеса
//     }
// }
// ```
//
// Каждый класс (`Car` и `Motorcycle`) реализует все методы, определенные в интерфейсе `IVehicle`, что позволяет создать единый интерфейс для работы с разными типами транспортных средств.
//
// ### Управление зависимостями (Dependency Injection)
//
// **Управление зависимостями** — это паттерн проектирования, который помогает управлять созданием зависимостей в классе. Этот подход позволяет внедрять (или "вводить") зависимости через конструктор, методы или свойства, вместо того чтобы создавать их внутри класса. Это делает код более чистым и облегчает его тестирование.
//
// #### Пример управления зависимостями
//
// Создадим класс `VehicleService`, который будет зависеть от интерфейса `IVehicle`:
//
// ```csharp
// public class VehicleService
// {
//     private readonly IVehicle _vehicle;
//
//     // Внедрение зависимости через конструктор
//     public VehicleService(IVehicle vehicle)
//     {
//         _vehicle = vehicle;
//     }
//
//     public void UseVehicle()
//     {
//         _vehicle.Start(); // Запускаем транспортное средство
//         Console.WriteLine($"У этого транспортного средства {_vehicle.GetNumberOfWheels()} колеса.");
//         _vehicle.Stop(); // Останавливаем транспортное средство
//     }
// }
// ```
//
// В этом примере класс `VehicleService` принимает в своем конструкторе объект, реализующий интерфейс `IVehicle`. Это позволяет `VehicleService` работать с любым объектом, который реализует `IVehicle`, обеспечивая гибкость и уменьшая связывание между классами.
//
// ### Использование классов
//
// Теперь давайте создадим объекты `Car` и `Motorcycle` и используем наш сервис:
//
// ```csharp
// IVehicle myCar = new Car(); // Создаем объект машины
// VehicleService carService = new VehicleService(myCar); // Передаем машину в сервис
// carService.UseVehicle(); // Используем сервис с машиной
//
// IVehicle myMotorcycle = new Motorcycle(); // Создаем объект мотоцикла
// VehicleService motorcycleService = new VehicleService(myMotorcycle); // Передаем мотоцикл в сервис
// motorcycleService.UseVehicle(); // Используем сервис с мотоциклом
//
// ```
//
// ### Результат выполнения
//
// При запуске данной программы будет следующий вывод:
//
// ```
// Машина запущена.
// У этого транспортного средства 4 колеса.
// Машина остановлена.
// Мотоцикл запущен.
// У этого транспортного средства 2 колеса.
// Мотоцикл остановлен.
// ```
//
// ### Заключение
//
// Использование интерфейсов и управления зависимостями позволяет создать более организованный и тестируемый код. Интерфейсы определяют стандартные поведения, а управление зависимостями снижает связность между компонентами. Это делает систему более гибкой и упрощает процесс её поддержки и расширения в будущем.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Vehicle, Car и Motorcycle ниже в блоке с применением интерфейса и абстактного класса:</h4>
//
// ----

// %%
public interface IVehicle
{
    void Start();
    void Stop();
    int GetNumberOfWheels();
}

public class Car : IVehicle
{
    public string Make { get; set; }
    public string Model { get; set; }

    public void Start()
    {
        Console.WriteLine($"{Make} {Model} запущена.");
    }

    public void Stop()
    {
        Console.WriteLine($"{Make} {Model} остановлена.");
    }

    public int GetNumberOfWheels()
    {
        return 4;
    }
}

public class Motorcycle : IVehicle
{
    public string Make { get; set; }
    public string Model { get; set; }

    public void Start()
    {
        Console.WriteLine($"{Make} {Model} запущен.");
    }

    public void Stop()
    {
        Console.WriteLine($"{Make} {Model} остановлен.");
    }

    public int GetNumberOfWheels()
    {
        return 2;
    }
}

public abstract class Vehicle : IVehicle
{
    public string Make { get; set; }
    public string Model { get; set; }

    public abstract void Start();
    public abstract void Stop();
    public abstract int GetNumberOfWheels();
}

public class VehicleService
{
    private readonly IVehicle _vehicle;

    public VehicleService(IVehicle vehicle)
    {
        _vehicle = vehicle;
    }

    public void UseVehicle()
    {
        _vehicle.Start();
        Console.WriteLine($"У этого транспортного средства {_vehicle.GetNumberOfWheels()} колеса.");
        _vehicle.Stop();
    }
}

IVehicle myCar = new Car { Make = "Toyota", Model = "Camry" };
VehicleService carService = new VehicleService(myCar);
carService.UseVehicle();

Console.WriteLine();

IVehicle myMotorcycle = new Motorcycle { Make = "Harley-Davidson", Model = "Street" };
VehicleService motorcycleService = new VehicleService(myMotorcycle);
motorcycleService.UseVehicle();

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (3-4 например Dog, Cat, Bird и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также реализовать управление зависимостями.

// %%
using System;

public interface IHungerManager
{
    void IncreaseHunger(int amount);
    void DecreaseHunger(int amount);
    bool IsVeryHungry();
    int GetCurrentHunger(); // Добавляем этот метод в интерфейс
}

public class HungerManager : IHungerManager
{
    private int _hungerLevel;

    public void IncreaseHunger(int amount)
    {
        _hungerLevel += amount;
        Console.WriteLine($"Уровень голода увеличен на {amount}. Текущий уровень: {_hungerLevel}");
    }

    public void DecreaseHunger(int amount)
    {
        _hungerLevel = Math.Max(0, _hungerLevel - amount);
        Console.WriteLine($"Уровень голода уменьшен на {amount}. Текущий уровень: {_hungerLevel}");
    }

    public bool IsVeryHungry()
    {
        return _hungerLevel >= 5;
    }

    public int GetCurrentHunger() // Реализуем метод
    {
        return _hungerLevel;
    }
}

public interface IAnimal
{
    void Speak();
    void Eat();
    void Sleep();
    int GetCurrentHungerLevel();
}

public class Animal : IAnimal
{
    public string Name { get; set; }
    public string Species { get; set; }
    protected IHungerManager _hungerManager;

    public Animal(IHungerManager hungerManager)
    {
        _hungerManager = hungerManager;
    }

    public virtual void Speak()
    {
        Console.WriteLine($"{Species} {Name} издает звук.");
    }

    public virtual void Eat()
    {
        _hungerManager.DecreaseHunger(2);
        Console.WriteLine($"{Species} {Name} ест.");
    }

    public virtual void Sleep()
    {
        Console.WriteLine($"{Species} {Name} спит.");
    }

    public int GetCurrentHungerLevel()
    {
        return _hungerManager.GetCurrentHunger(); // Теперь этот метод доступен
    }

    public void MakeHungry()
    {
        _hungerManager.IncreaseHunger(3);
        if (_hungerManager.IsVeryHungry())
        {
            Console.WriteLine($"{Species} {Name} очень голоден!");
        }
    }
}

public class Dog : Animal
{
    public string Breed { get; set; }

    public Dog(IHungerManager hungerManager) : base(hungerManager) { }

    public override void Speak()
    {
        Console.WriteLine($"{Species} {Name} лает: Гав-гав!, порода {Breed}");
    }

    public override void Eat()
    {
        Console.WriteLine($"{Species} {Name} ест кость, порода {Breed}");
        _hungerManager.DecreaseHunger(3);
    }

    public override void Sleep()
    {
        Console.WriteLine($"{Species} {Name} спит в будке, порода {Breed}");
    }

    public void Play()
    {
        Console.WriteLine($"{Species} {Name} играет с мячиком");
        _hungerManager.IncreaseHunger(1);
    }
}

public class Cat : Animal
{
    public string Color { get; set; }

    public Cat(IHungerManager hungerManager) : base(hungerManager) { }

    public override void Speak()
    {
        Console.WriteLine($"{Species} {Name} мяукает: Мяу!, цвет {Color}");
    }

    public override void Eat()
    {
        Console.WriteLine($"{Species} {Name} ест рыбу, цвет {Color}");
        _hungerManager.DecreaseHunger(2);
    }

    public override void Sleep()
    {
        Console.WriteLine($"{Species} {Name} спит на коврике, цвет {Color}");
    }

    public void Purr()
    {
        Console.WriteLine($"{Species} {Name} мурлычет: Муррр...");
    }
}

public class Bird : Animal
{
    public string WingSpan { get; set; }

    public Bird(IHungerManager hungerManager) : base(hungerManager) { }

    public override void Speak()
    {
        Console.WriteLine($"{Species} {Name} чирикает: Чик-чирик!, размах крыльев {WingSpan}");
    }

    public override void Eat()
    {
        Console.WriteLine($"{Species} {Name} клюет зерно, размах крыльев {WingSpan}");
        _hungerManager.DecreaseHunger(1);
    }

    public override void Sleep()
    {
        Console.WriteLine($"{Species} {Name} спит в гнезде, размах крыльев {WingSpan}");
    }

    public void Fly()
    {
        Console.WriteLine($"{Species} {Name} летает по кругу!");
        _hungerManager.IncreaseHunger(1);
    }
}

Console.WriteLine("=== Демонстрация животных с управлением зависимостями ===\n");

IHungerManager dogHunger = new HungerManager();
IHungerManager catHunger = new HungerManager();
IHungerManager birdHunger = new HungerManager();

Dog myDog = new Dog(dogHunger) 
{ 
    Name = "Бадди", 
    Species = "Собака", 
    Breed = "Лабрадор" 
};

Cat myCat = new Cat(catHunger) 
{ 
    Name = "Мурка", 
    Species = "Кошка", 
    Color = "Серый" 
};

Bird myBird = new Bird(birdHunger) 
{ 
    Name = "Кеша", 
    Species = "Попугай", 
    WingSpan = "15 см" 
};

Console.WriteLine("Собака");
myDog.MakeHungry();
myDog.Speak();
myDog.Play();
myDog.Eat();
myDog.Sleep();
Console.WriteLine($"Уровень голода: {myDog.GetCurrentHungerLevel()}\n");

Console.WriteLine("Кошка");
myCat.MakeHungry();
myCat.Speak();
myCat.Eat();
myCat.Purr();
myCat.Sleep();
Console.WriteLine($"Уровень голода: {myCat.GetCurrentHungerLevel()}\n");

Console.WriteLine("Птица");
myBird.MakeHungry();
myBird.Speak();
myBird.Fly();
myBird.Eat();
myBird.Sleep();
Console.WriteLine($"Уровень голода: {myBird.GetCurrentHungerLevel()}\n");

Console.WriteLine("Работа через интерфейс");
IAnimal[] animals = { myDog, myCat, myBird };

foreach (IAnimal animal in animals)
{
    Console.WriteLine($"--- {animal.GetType().Name} ---");
    animal.Speak();
    animal.Eat();
    animal.Sleep();
    Console.WriteLine($"Уровень голода: {animal.GetCurrentHungerLevel()}\n");
}
// Out:
// === Демонстрация животных с управлением зависимостями ===
//
// Собака
// Уровень голода увеличен на 3. Текущий уровень: 3
// Собака Бадди лает: Гав-гав!, порода Лабрадор
// Собака Бадди играет с мячиком
// Уровень голода увеличен на 1. Текущий уровень: 4
// Собака Бадди ест кость, порода Лабрадор
// Уровень голода уменьшен на 3. Текущий уровень: 1
// Собака Бадди спит в будке, порода Лабрадор
// Уровень голода: 1
//
// Кошка
// Уровень голода увеличен на 3. Текущий уровень: 3
// Кошка Мурка мяукает: Мяу!, цвет Серый
// Кошка Мурка ест рыбу, цвет Серый
// Уровень голода уменьшен на 2. Текущий уровень: 1
// Кошка Мурка мурлычет: Муррр...
// Кошка Мурка спит на коврике, цвет Серый
// Уровень голода: 1
//
// Птица
// Уровень голода увеличен на 3. Текущий уровень: 3
// Попугай Кеша чирикает: Чик-чирик!, размах крыльев 15 см
// Попугай Кеша летает по кругу!
// Уровень голода увеличен на 1. Текущий уровень: 4
// Попугай Кеша клюет зерно, размах крыльев 15 см
// Уровень голода уменьшен на 1. Текущий уровень: 3
// Попугай Кеша спит в гнезде, размах крыльев 15 см
// Уровень голода: 3
//
// Работа через интерфейс
// --- Dog ---
// Собака Бадди лает: Гав-гав!, порода Лабрадор
// Собака Бадди ест кость, порода Лабрадор
// Уровень голода уменьшен на 3. Текущий уровень: 0
// Собака Бадди спит в будке, порода Лабрадор
// Уровень голода: 0
//
// --- Cat ---
// Кошка Мурка мяукает: Мяу!, цвет Серый
// Кошка Мурка ест рыбу, цвет Серый
// Уровень голода уменьшен на 2. Текущий уровень: 0
// Кошка Мурка спит на коврике, цвет Серый
// Уровень голода: 0
//
// --- Bird ---
// Попугай Кеша чирикает: Чик-чирик!, размах крыльев 15 см
// Попугай Кеша клюет зерно, размах крыльев 15 см
// Уровень голода уменьшен на 1. Текущий уровень: 2
// Попугай Кеша спит в гнезде, размах крыльев 15 см
// Уровень голода: 2
