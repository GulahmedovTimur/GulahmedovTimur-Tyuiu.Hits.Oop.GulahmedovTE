// %% [markdown]
// <h1 style="color:DodgerBlue">Делегаты, лямбда-выражения и события<T></h1>

// %% [markdown]
// Делегаты, лямбда-выражения и события являются важными концепциями в C#, которые позволяют работать с методами как с объектами, писать краткий код и управлять реакциями на события. Рассмотрим их на примере гипотетических классов `Transport`, `Car`, и `Bike`.
//
// ### Делегаты
//
// **Делегат** — это тип безопасного указателя на метод, похожий на функцию в C или C++. Делегаты в C# используются для передачи методов как параметров, а также для создания обратных вызовов.
//
// **Пример:**
//
// Создадим делегат, который может ссылаться на методы, выводящие информацию о транспортном средстве:
//
// ```csharp
// public delegate void DisplayDelegate();
//
// public class Transport
// {
//     public string Model { get; set; }
//     public string Manufacturer { get; set; }
//
//     public Transport(string model, string manufacturer)
//     {
//         Model = model;
//         Manufacturer = manufacturer;
//     }
//
//     public virtual void DisplayInfo()
//     {
//         Console.WriteLine($"Model: {Model}, Manufacturer: {Manufacturer}");
//     }
// }
// ```
//
// Используем делегат:
//
// ```csharp
//
//         Car car = new Car("Model S", "Tesla", 4);
//         Bike bike = new Bike("Speedster", "Giant", true);
//
//         // Присваиваем делегату метод DisplayInfo
//         DisplayDelegate displayCar = car.DisplayInfo;
//         DisplayDelegate displayBike = bike.DisplayInfo;
//
//         // Вызов методов через делегаты
//         displayCar();
//         displayBike();
//
//
//
//
// public class Car : Transport
// {
//     public int NumberOfDoors { get; set; }
//
//     public Car(string model, string manufacturer, int numberOfDoors)
//         : base(model, manufacturer)
//     {
//         NumberOfDoors = numberOfDoors;
//     }
//
//     public override void DisplayInfo()
//     {
//         base.DisplayInfo();
//         Console.WriteLine($"Number of Doors: {NumberOfDoors}");
//     }
// }
//
// public class Bike : Transport
// {
//     public bool HasCarrier { get; set; }
//
//     public Bike(string model, string manufacturer, bool hasCarrier)
//         : base(model, manufacturer)
//     {
//         HasCarrier = hasCarrier;
//     }
//
//     public override void DisplayInfo()
//     {
//         base.DisplayInfo();
//         Console.WriteLine($"Has Carrier: {HasCarrier}");
//     }
// }
// ```
//
// ### Лямбда-выражения
//
// **Лямбда-выражения** позволяют вам писать анонимные методы в более краткой форме. Это часто используется в LINQ и асинхронном программировании.
//
// **Пример:**
//
// ```csharp
// using System;
// using System.Collections.Generic;
// using System.Linq;
//
//
//
// List<Transport> transports = new List<Transport>
// {
//     new Car("Model S", "Tesla", 4),
//     new Bike("Speedster", "Giant", true),
//     new Car("Model 3", "Tesla", 4),
// };
//
// // Используем лямбда-выражение для фильтрации транспортных средств
// var teslaCars = transports.OfType<Car>().Where(c => c.Manufacturer == "Tesla");
//
// foreach (var car in teslaCars)
// {
//     car.DisplayInfo();
// }
//
//
// ```
//
// ### События
//
// **События** используются для оповещения подписчиков о случившихся действиях, предоставляя более высокоуровневый способ взаимодействия между различными частями кода.
//
// **Пример:**
//
// ```csharp
// public class Transport
// {
//     public string Model { get; set; }
//     public string Manufacturer { get; set; }
//
//     public delegate void TransportHandler(string message);
//     public event TransportHandler TransportUpdated;
//
//     public void UpdateModel(string newModel)
//     {
//         Model = newModel;
//         // Вызываем событие после обновления модели
//         TransportUpdated?.Invoke($"Model updated to {newModel}");
//     }
// }
//
//
//
// Transport transport = new Transport { Model = "Old Model", Manufacturer = "Generic" };
// // Подписываем метод на событие
// transport.TransportUpdated += OnTransportUpdated;
// // Обновляем модель; это вызовет событие
// transport.UpdateModel("New Model");
//
//
// static void OnTransportUpdated(string message)
// {
//     Console.WriteLine(message);
// }
// ```
//
// ### Объяснения и комментарии:
//
// - **Делегаты**: Тип данных, который можно использовать для хранения ссылок на методы. Полезно для обратных вызовов и передачи методов.
//
// - **Лямбда-выражения**: Более краткая запись анонимных методов, часто используется в LINQ для фильтрации, проекций и агрегаций.
//
// - **События**: Механизм уведомления объектов об изменениях состояния или других действиях. Позволяют подписываться на события в одной части программы и реакцию на них в другой.
//
// Эти механизмы делают программу гибкой и более структурированной, обеспечивая четкое отделение логики и упрощая повторное использование кода.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов `Transport`, `Car`, и `Bike` ниже в блоке с применением  делегатов, лямда-выражений и событий</h4>
//
// ----

// %%
public delegate void DisplayDelegate();

public class Transport
{
    public string Model { get; set; }
    public string Manufacturer { get; set; }

    public Transport(string model, string manufacturer)
    {
        Model = model;
        Manufacturer = manufacturer;
    }

    public virtual void DisplayInfo()
    {
        Console.WriteLine($"Model: {Model}, Manufacturer: {Manufacturer}");
    }

    // Делегат и событие для уведомления об обновлении модели
    public delegate void TransportHandler(string message);
    public event TransportHandler TransportUpdated;

    public void UpdateModel(string newModel)
    {
        Model = newModel;
        TransportUpdated?.Invoke($"Model updated to {newModel}");
    }
}

public class Car : Transport
{
    public int NumberOfDoors { get; set; }

    public Car(string model, string manufacturer, int numberOfDoors)
        : base(model, manufacturer)
    {
        NumberOfDoors = numberOfDoors;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Number of Doors: {NumberOfDoors}");
    }
}

public class Bike : Transport
{
    public bool HasCarrier { get; set; }

    public Bike(string model, string manufacturer, bool hasCarrier)
        : base(model, manufacturer)
    {
        HasCarrier = hasCarrier;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Has Carrier: {HasCarrier}");
    }
}


        Car car = new Car("Model S", "Tesla", 4);
        Bike bike = new Bike("Speedster", "Giant", true);

        // Делегаты
        DisplayDelegate displayCar = car.DisplayInfo;
        DisplayDelegate displayBike = bike.DisplayInfo;

        displayCar();
        displayBike();

        // Лямбда-выражения для работы с коллекцией
        List<Transport> transports = new List<Transport>
        {
            new Car("Model 3", "Tesla", 4),
            new Bike("Mountain Explorer", "Giant", true),
            car,
            bike
        };

        var teslaCars = transports.OfType<Car>().Where(c => c.Manufacturer == "Tesla");
        Console.WriteLine("\nFiltered Tesla Cars:");
        foreach (var c in teslaCars)
        {
            c.DisplayInfo();
        }

        // События
        car.TransportUpdated += OnTransportUpdated;
        car.UpdateModel("Model X"); // вызовет событие

        bike.TransportUpdated += OnTransportUpdated;
        bike.UpdateModel("Speedster Pro"); // вызовет событие
    }

    static void OnTransportUpdated(string message)
    {
        Console.WriteLine($"Event: {message}");
    }

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (3-4 например Dog, Cat, Bird и так далее) с применением  делегатов, лямда-выражений и событий.

// %%
using System;
using System.Collections.Generic;
using System.Linq;

public delegate void AnimalDelegate();

public class Animal
{
    public string Name { get; set; }
    public int Age { get; set; }

    public Animal(string name, int age)
    {
        Name = name;
        Age = age;
    }

    public virtual void DisplayInfo()
    {
        Console.WriteLine($"Имя: {Name}, Возраст: {Age} лет");
    }

    public delegate void AnimalHandler(string message);
    public event AnimalHandler AnimalUpdated;

    public void UpdateName(string newName)
    {
        Name = newName;
        AnimalUpdated?.Invoke($"Имя животного изменено на {newName}");
    }

    public virtual void MakeSound()
    {
        Console.WriteLine("Животное издает звук");
    }
}

public class Dog : Animal
{
    public string Breed { get; set; }
    public bool IsTrained { get; set; }

    public Dog(string name, int age, string breed, bool isTrained)
        : base(name, age)
    {
        Breed = breed;
        IsTrained = isTrained;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Порода: {Breed}, Дрессирован: {IsTrained}");
    }

    public override void MakeSound()
    {
        Console.WriteLine("Гав! Гав!");
    }

    public void Fetch()
    {
        Console.WriteLine($"{Name} приносит мячик!");
    }
}

public class Cat : Animal
{
    public string Color { get; set; }
    public bool IsIndoor { get; set; }

    public Cat(string name, int age, string color, bool isIndoor)
        : base(name, age)
    {
        Color = color;
        IsIndoor = isIndoor;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Цвет: {Color}, Домашний: {IsIndoor}");
    }

    public override void MakeSound()
    {
        Console.WriteLine("Мяу! Мяу!");
    }

    public void Purr()
    {
        Console.WriteLine($"{Name} мурлычет от удовольствия");
    }
}

public class Bird : Animal
{
    public double Wingspan { get; set; }
    public bool CanFly { get; set; }

    public Bird(string name, int age, double wingspan, bool canFly)
        : base(name, age)
    {
        Wingspan = wingspan;
        CanFly = canFly;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Размах крыльев: {Wingspan}см, Умеет летать: {CanFly}");
    }

    public override void MakeSound()
    {
        Console.WriteLine("Чик-чирик! Чик-чирик!");
    }

    public void Fly()
    {
        if (CanFly)
            Console.WriteLine($"{Name} летит высоко в небе!");
        else
            Console.WriteLine($"{Name} не умеет летать");
    }
}

public class Fish : Animal
{
    public string WaterType { get; set; }
    public bool HasScales { get; set; }

    public Fish(string name, int age, string waterType, bool hasScales)
        : base(name, age)
    {
        WaterType = waterType;
        HasScales = hasScales;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Тип воды: {WaterType}, Есть чешуя: {HasScales}");
    }

    public override void MakeSound()
    {
        Console.WriteLine("Буль-буль...");
    }

    public void Swim()
    {
        Console.WriteLine($"{Name} плавает в {WaterType} воде");
    }
}



Dog dog = new Dog("Бади", 3, "Золотистый ретривер", true);
Cat cat = new Cat("Усики", 2, "Серый", true);
Bird bird = new Bird("Чижик", 1, 15.5, true);
Fish fish = new Fish("Немо", 1, "Соленая", true);

AnimalDelegate displayDog = dog.DisplayInfo;
AnimalDelegate displayCat = cat.DisplayInfo;
AnimalDelegate displayBird = bird.DisplayInfo;
AnimalDelegate displayFish = fish.DisplayInfo;

Console.WriteLine("=== Использование делегатов ===");
displayDog();
displayCat();
displayBird();
displayFish();

List<Animal> animals = new List<Animal>
{
    new Dog("Макс", 5, "Немецкая овчарка", true),
    new Cat("Луна", 3, "Черная", false),
    new Bird("Попка", 2, 20.0, true),
    new Fish("Дори", 1, "Соленая", true),
    dog,
    cat,
    bird,
    fish
};

Console.WriteLine("\n=== Использование лямбда-выражений ===");

var trainedDogs = animals.OfType<Dog>().Where(d => d.IsTrained);
Console.WriteLine("\nДрессированные собаки:");
trainedDogs.ToList().ForEach(d => d.DisplayInfo());

var indoorCats = animals.OfType<Cat>().Where(c => c.IsIndoor);
Console.WriteLine("\nДомашние кошки:");
indoorCats.ToList().ForEach(c => c.DisplayInfo());

var flyingBirds = animals.OfType<Bird>().Where(b => b.CanFly);
Console.WriteLine("\nЛетающие птицы:");
flyingBirds.ToList().ForEach(b => b.DisplayInfo());

var saltwaterFish = animals.OfType<Fish>().Where(f => f.WaterType == "Соленая");
Console.WriteLine("\nМорские рыбы:");
saltwaterFish.ToList().ForEach(f => f.DisplayInfo());

Console.WriteLine("\n=== Звуки животных через лямбда-выражения ===");
animals.ForEach(animal => animal.MakeSound());

Console.WriteLine("\n=== Молодые животные (Возраст < 3 лет) ===");
var youngAnimals = animals.Where(a => a.Age < 3);
youngAnimals.ToList().ForEach(a => a.DisplayInfo());

Console.WriteLine("\n=== Демонстрация событий ===");

dog.AnimalUpdated += OnAnimalUpdated;
cat.AnimalUpdated += OnAnimalUpdated;
bird.AnimalUpdated += OnAnimalUpdated;
fish.AnimalUpdated += OnAnimalUpdated;

dog.UpdateName("Бади Младший");
cat.UpdateName("Мурка");
bird.UpdateName("Небо");
fish.UpdateName("Пузырек");

Console.WriteLine("\n=== Особые способности ===");

Action[] animalActions = {
    () => dog.Fetch(),
    () => cat.Purr(),
    () => bird.Fly(),
    () => fish.Swim()
};

foreach (var action in animalActions)
{
    action();
}

Console.WriteLine("\n=== Сложные лямбда-запросы ===");

var animalsByNameLength = animals.OrderBy(a => a.Name.Length);
Console.WriteLine("Животные отсортированы по длине имени:");
animalsByNameLength.ToList().ForEach(a => Console.WriteLine($"{a.Name} ({a.Name.Length} букв)"));

var animalsGroupedByType = animals.GroupBy(a => a.GetType().Name);
foreach (var group in animalsGroupedByType)
{
    Console.WriteLine($"\n{group.Key}:");
    group.ToList().ForEach(a => Console.WriteLine($"  - {a.Name}"));
}

static void OnAnimalUpdated(string message)
{
Console.WriteLine($"Событие животного: {message}");
}
// Out:
// === Использование делегатов ===
// Имя: Бади, Возраст: 3 лет
// Порода: Золотистый ретривер, Дрессирован: True
// Имя: Усики, Возраст: 2 лет
// Цвет: Серый, Домашний: True
// Имя: Чижик, Возраст: 1 лет
// Размах крыльев: 15,5см, Умеет летать: True
// Имя: Немо, Возраст: 1 лет
// Тип воды: Соленая, Есть чешуя: True
//
// === Использование лямбда-выражений ===
//
// Дрессированные собаки:
// Имя: Макс, Возраст: 5 лет
// Порода: Немецкая овчарка, Дрессирован: True
// Имя: Бади, Возраст: 3 лет
// Порода: Золотистый ретривер, Дрессирован: True
//
// Домашние кошки:
// Имя: Усики, Возраст: 2 лет
// Цвет: Серый, Домашний: True
//
// Летающие птицы:
// Имя: Попка, Возраст: 2 лет
// Размах крыльев: 20см, Умеет летать: True
// Имя: Чижик, Возраст: 1 лет
// Размах крыльев: 15,5см, Умеет летать: True
//
// Морские рыбы:
// Имя: Дори, Возраст: 1 лет
// Тип воды: Соленая, Есть чешуя: True
// Имя: Немо, Возраст: 1 лет
// Тип воды: Соленая, Есть чешуя: True
//
// === Звуки животных через лямбда-выражения ===
// Гав! Гав!
// Мяу! Мяу!
// Чик-чирик! Чик-чирик!
// Буль-буль...
// Гав! Гав!
// Мяу! Мяу!
// Чик-чирик! Чик-чирик!
// Буль-буль...
//
// === Молодые животные (Возраст < 3 лет) ===
// Имя: Попка, Возраст: 2 лет
// Размах крыльев: 20см, Умеет летать: True
// Имя: Дори, Возраст: 1 лет
// Тип воды: Соленая, Есть чешуя: True
// Имя: Усики, Возраст: 2 лет
// Цвет: Серый, Домашний: True
// Имя: Чижик, Возраст: 1 лет
// Размах крыльев: 15,5см, Умеет летать: True
// Имя: Немо, Возраст: 1 лет
// Тип воды: Соленая, Есть чешуя: True
//
// === Демонстрация событий ===
// Событие животного: Имя животного изменено на Бади Младший
// Событие животного: Имя животного изменено на Мурка
// Событие животного: Имя животного изменено на Небо
// Событие животного: Имя животного изменено на Пузырек
//
// === Особые способности ===
// Бади Младший приносит мячик!
// Мурка мурлычет от удовольствия
// Небо летит высоко в небе!
// Пузырек плавает в Соленая воде
//
// === Сложные лямбда-запросы ===
// Животные отсортированы по длине имени:
// Макс (4 букв)
// Луна (4 букв)
// Дори (4 букв)
// Небо (4 букв)
// Попка (5 букв)
// Мурка (5 букв)
// Пузырек (7 букв)
// Бади Младший (12 букв)
//
// Dog:
//   - Макс
//   - Бади Младший
//
// Cat:
//   - Луна
//   - Мурка
//
// Bird:
//   - Попка
//   - Небо
//
// Fish:
//   - Дори
//   - Пузырек
