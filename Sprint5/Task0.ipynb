// %% [markdown]
// <h1 style="color:DodgerBlue">Коллекции в .NET </h1>

// %% [markdown]
// Коллекции в .NET - это структуры данных, которые позволяют организовать и управлять наборами объектов. Они предоставляют эффективные способы хранения, доступа и манипулирования данными. Вот основные типы коллекций в .NET:
//
// ### 1. Статические коллекции
//
// Статические коллекции являются неизменяемыми и могут содержать только один экземпляр заданного типа данных.
//
// - `System.Collections.Generic.EmptyCollection<T>`
// - `System.Collections.Generic.Singleton<T>`
// - `System.Collections.ObjectModel.ReadOnlyCollection<T>`
//
// ### 2. Неупорядоченные коллекции
//
// Неупорядоченные коллекции не гарантируют порядок элементов.
//
// - `System.Collections.Generic.List<T>` - динамический массив
// - `System.Collections.Generic.Dictionary<TKey,TValue>` - словарь (ассоциативный массив)
// - `System.Collections.Generic.HashSet<T>` - множество уникальных элементов
// - `System.Collections.Generic.SortedSet<T>` - отсортированный набор элементов
//
// ### 3. Сортированные коллекции
//
// Сортированные коллекции поддерживают упорядоченный доступ и могут быть отсортированы по определенному критерию.
//
// - `System.Collections.Generic.SortedDictionary<TKey,TValue>`
// - `System.Collections.Generic.SortedSet<T>`
// - `System.Collections.Generic.SortedList<TKey,TValue>`
//
// ### 4. Множества
//
// Множества содержат только уникальные элементы.
//
// - `System.Collections.Generic.HashSet<T>`
// - `System.Collections.Generic.ISet<T>` - интерфейс для неупорядоченных множеств
//
// ### 5. Ключевые коллекции
//
// Ключевые коллекции используются для хранения пар ключ-значение.
//
// - `System.Collections.Generic.Dictionary<TKey,TValue>`
// - `System.Collections.Generic.KeyedCollection<TKey,TElement>`
// - `System.Collections.Generic.Lookup<TKey,TValue>`
//
// ### 6. Коллекции с ограниченным размером
//
// Эти коллекции имеют фиксированный или максимальный размер.
//
// - `System.Collections.Generic.Stack<T>` - стек
// - `System.Collections.Generic.Queue<T>` - очередь
// - `System.Collections.Generic.ConcurrentQueue<T>` - потокобезопасная очередь
//
// ### 7. Потокобезопасные коллекции
//
// Потокобезопасные коллекции обеспечивают безопасность доступа из нескольких потоков.
//
// - `System.Collections.Concurrent.ConcurrentDictionary<TKey,TValue>`
// - `System.Collections.Concurrent.ConcurrentBag<T>`
// - `System.Collections.Concurrent.BlockingCollection<T>`
//
// ### 8. Специализированные коллекции
//
// Специализированные коллекции предназначены для конкретных задач.
//
// - `System.Collections.Generic.BCLPortabilityLibrary.Collections.Generic.MultiMap<TKey,TKey2,TValue>`
// - `System.Collections.Generic.BCLPortabilityLibrary.Collections.Generic.MultiDictionary<TKey,TValue>`
//
// Это основные типы коллекций в .NET Framework и .NET Core. Выбор конкретной коллекции зависит от требований вашего проекта, таких как необходимость сортировки, потокобезопасности или специфики использования данных.

// %% [markdown]
// Работа с `List<T>` и `Dictionary<TKey, TValue>` в C# позволяет эффективно управлять коллекциями объектов различных типов. Давайте рассмотрим, как это можно сделать на примере классов `Transport`, `Car`, и `Bike`.
//
// ### Класс Transport и его производные
//
// Начнем с базового класса `Transport`, который будет основой для классов `Car` и `Bike`.
//
// ```csharp
// public class Transport
// {
//     public string Model { get; set; }
//     public string Manufacturer { get; set; }
//
//     public Transport(string model, string manufacturer)
//     {
//         Model = model;
//         Manufacturer = manufacturer;
//     }
//
//     public virtual void DisplayInfo()
//     {
//         Console.WriteLine($"Модель: {Model}, Производитель: {Manufacturer}");
//     }
// }
//
// public class Car : Transport
// {
//     public int NumberOfDoors { get; set; }
//
//     public Car(string model, string manufacturer, int numberOfDoors)
//         : base(model, manufacturer)
//     {
//         NumberOfDoors = numberOfDoors;
//     }
//
//     public override void DisplayInfo()
//     {
//         base.DisplayInfo();
//         Console.WriteLine($"Количество дверей: {NumberOfDoors}");
//     }
// }
//
// public class Bike : Transport
// {
//     public bool HasCarrier { get; set; }
//
//     public Bike(string model, string manufacturer, bool hasCarrier)
//         : base(model, manufacturer)
//     {
//         HasCarrier = hasCarrier;
//     }
//
//     public override void DisplayInfo()
//     {
//         base.DisplayInfo();
//         Console.WriteLine($"Имеет наситель: {HasCarrier}");
//     }
// }
// ```
//
// ### Работа с List<T>
//
// Теперь давайте посмотрим, как работать с `List<T>` для хранения коллекции объектов транспорта.
//
// ```csharp
// using System;
// using System.Collections.Generic;
//
//
// // Создаем список Transport
// List<Transport> transportList = new List<Transport>();
//
// // Добавляем объекты Car и Bike в список
// transportList.Add(new Car("Model S", "Tesla", 4));
// transportList.Add(new Bike("Mountain Explorer", "Giant", true));
//
// // Перебираем и выводим информацию обо всех транспортных средствах
// foreach (var transport in transportList)
// {
//     transport.DisplayInfo();
//     Console.WriteLine();
// }
//
// ```
//
// ### Работа с Dictionary<TKey, TValue>
//
// Теперь давайте создадим коллекцию, которая будет хранить объекты `Transport`, используя `Dictionary<TKey, TValue>`, где ключом будет, например, регистрационный номер транспорта.
//
// ```csharp
// using System;
// using System.Collections.Generic;
//
// // Создаем словарь с ключом типа string и значением типа Transport
// Dictionary<string, Transport> transportDictionary = new Dictionary<string, Transport>();
//
// // Добавляем объекты с уникальными ключами
// transportDictionary.Add("TSL123", new Car("Model S", "Tesla", 4));
// transportDictionary.Add("BIK456", new Bike("Mountain Explorer", "Giant", true));
//
// // Поиск и вывод информации о транспорте по ключу
// if (transportDictionary.TryGetValue("TSL123", out Transport foundTransport))
// {
//     Console.WriteLine("Найденый траснпорт:");
//     foundTransport.DisplayInfo();
// }
// else
// {
//     Console.WriteLine("Транспорт не найден");
// }
//
// ```
//
// ### Объяснения и примеры использования:
//
// - **List<T>**: Используется, когда порядок элементов важен и возможны дубликаты. Вы можете добавлять, удалять, итерировать и изменять элементы по индексу.
//
// - **Dictionary<TKey,TValue>**: Подходит, когда нужно организовать элементы по уникальным ключам для быстрого доступа. Это удобно для случаев, когда вы хотите находить элемент по ключу, как регистрационный номер в примере.
//
// Эти структуры данных предоставляют мощные и гибкие возможности для управления коллекциями объектов, каждая из которых имеет свои преимущества в определённых ситуациях.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов `Transport`, `Car`, и `Bike` ниже в блоке с применением  List<T> и  Dictionary<TKey,TValue></h4>
//
// ----

// %%
using System;
using System.Collections.Generic;
using System.Linq;


public class Transport
{
    public string Model { get; set; }
    public string Manufacturer { get; set; }
    public int Year { get; set; }
    public decimal Price { get; set; }

    public Transport(string model, string manufacturer, int year, decimal price)
    {
        Model = model;
        Manufacturer = manufacturer;
        Year = year;
        Price = price;
    }

    public virtual void DisplayInfo()
    {
        Console.WriteLine($"Модель: {Model}, Производитель: {Manufacturer}, Год: {Year}, Цена: {Price:C}");
    }

    public virtual void Start()
    {
        Console.WriteLine($"{Model} запущен");
    }

    public virtual void Stop()
    {
        Console.WriteLine($"{Model} остановлен");
    }
}


public class Car : Transport
{
    public int NumberOfDoors { get; set; }
    public string FuelType { get; set; }
    public bool HasAirConditioning { get; set; }

    public Car(string model, string manufacturer, int year, decimal price, int numberOfDoors, string fuelType, bool hasAirConditioning)
        : base(model, manufacturer, year, price)
    {
        NumberOfDoors = numberOfDoors;
        FuelType = fuelType;
        HasAirConditioning = hasAirConditioning;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Количество дверей: {NumberOfDoors}, Тип топлива: {FuelType}, Кондиционер: {(HasAirConditioning ? "Есть" : "Нет")}");
    }

    public void OpenTrunk()
    {
        Console.WriteLine($"Багажник {Model} открыт");
    }
}


public class Bike : Transport
{
    public bool HasCarrier { get; set; }
    public int GearCount { get; set; }
    public string BikeType { get; set; }

    public Bike(string model, string manufacturer, int year, decimal price, bool hasCarrier, int gearCount, string bikeType)
        : base(model, manufacturer, year, price)
    {
        HasCarrier = hasCarrier;
        GearCount = gearCount;
        BikeType = bikeType;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Имеет багажник: {(HasCarrier ? "Да" : "Нет")}, Количество передач: {GearCount}, Тип: {BikeType}");
    }

    public void RingBell()
    {
        Console.WriteLine($"Звонок на {Model}: Динь-динь!");
    }
}



        Console.WriteLine("=== Работа с List<Transport> ===\n");

        List<Transport> transportList = new List<Transport>();

        transportList.Add(new Car("Model S", "Tesla", 2023, 95000m, 4, "Электричество", true));
        transportList.Add(new Car("Camry", "Toyota", 2022, 35000m, 4, "Бензин", true));
        transportList.Add(new Bike("Mountain Explorer", "Giant", 2021, 1500m, true, 21, "Горный"));
        transportList.Add(new Bike("Road Master", "Trek", 2023, 2000m, false, 18, "Шоссейный"));
        transportList.Add(new Car("X5", "BMW", 2023, 75000m, 4, "Дизель", true));

        Console.WriteLine("Все транспортные средства в списке:");
        foreach (var transport in transportList)
        {
            transport.DisplayInfo();
            Console.WriteLine();
        }

        Console.WriteLine("\n=== Операции со списком ===\n");

        Console.WriteLine($"Общее количество транспорта: {transportList.Count}");

        transportList.RemoveAt(1);
        Console.WriteLine($"После удаления элемента по индексу 1: {transportList.Count} элементов");

        Transport firstTransport = transportList[0];
        Console.WriteLine("\nПервый элемент списка:");
        firstTransport.DisplayInfo();

        Console.WriteLine("\n--- Только автомобили ---");
        foreach (var transport in transportList)
        {
            if (transport is Car car)
            {
                car.DisplayInfo();
                car.OpenTrunk();
                Console.WriteLine();
            }
        }

        Console.WriteLine("--- Только велосипеды ---");
        foreach (var transport in transportList)
        {
            if (transport is Bike bike)
            {
                bike.DisplayInfo();
                bike.RingBell();
                Console.WriteLine();
            }
        }

        List<Transport> expensiveTransport = transportList.FindAll(t => t.Price > 50000);
        Console.WriteLine($"\nТранспорт дороже $50,000: {expensiveTransport.Count} единиц");
        foreach (var transport in expensiveTransport)
        {
            Console.WriteLine($"- {transport.Model}: {transport.Price:C}");
        }

        transportList.Sort((t1, t2) => t1.Price.CompareTo(t2.Price));
        Console.WriteLine("\nСписок отсортирован по цене (по возрастанию):");
        foreach (var transport in transportList)
        {
            Console.WriteLine($"{transport.Model}: {transport.Price:C}");
        }

        Console.WriteLine("\n\n=== Работа с Dictionary<string, Transport> ===\n");

        Dictionary<string, Transport> transportDictionary = new Dictionary<string, Transport>();

        transportDictionary.Add("TSL123", new Car("Model S", "Tesla", 2023, 95000m, 4, "Электричество", true));
        transportDictionary.Add("TOY456", new Car("Camry", "Toyota", 2022, 35000m, 4, "Бензин", true));
        transportDictionary.Add("BIK789", new Bike("Mountain Explorer", "Giant", 2021, 1500m, true, 21, "Горный"));
        transportDictionary.Add("BIK101", new Bike("Road Master", "Trek", 2023, 2000m, false, 18, "Шоссейный"));
        transportDictionary.Add("BMW202", new Car("X5", "BMW", 2023, 75000m, 4, "Дизель", true));

        Console.WriteLine("Все транспортные средства в словаре:");
        foreach (var kvp in transportDictionary)
        {
            Console.WriteLine($"\nРегистрационный номер: {kvp.Key}");
            kvp.Value.DisplayInfo();
        }

        Console.WriteLine("\n\n=== Поиск по ключу ===\n");

        string searchKey = "TSL123";
        if (transportDictionary.TryGetValue(searchKey, out Transport foundTransport))
        {
            Console.WriteLine($"Найден транспорт с номером {searchKey}:");
            foundTransport.DisplayInfo();
            foundTransport.Start();
            foundTransport.Stop();
        }
        else
        {
            Console.WriteLine("Транспорт не найден");
        }

        Console.WriteLine("\n=== Проверка наличия ключа ===\n");

        string checkKey = "BIK789";
        if (transportDictionary.ContainsKey(checkKey))
        {
            Console.WriteLine($"Транспорт с номером {checkKey} существует");
            Console.WriteLine($"Это: {transportDictionary[checkKey].Model}");
        }

        Console.WriteLine("\n=== Удаление элемента ===\n");

        string removeKey = "TOY456";
        if (transportDictionary.Remove(removeKey))
        {
            Console.WriteLine($"Транспорт с номером {removeKey} успешно удален");
            Console.WriteLine($"Осталось элементов в словаре: {transportDictionary.Count}");
        }

        Console.WriteLine("\n=== Получение всех ключей ===\n");

        Console.WriteLine("Все регистрационные номера:");
        foreach (var key in transportDictionary.Keys)
        {
            Console.WriteLine($"- {key}");
        }

        Console.WriteLine("\n=== Получение всех значений ===\n");

        Console.WriteLine("Все транспортные средства:");
        foreach (var transport in transportDictionary.Values)
        {
            Console.WriteLine($"- {transport.Manufacturer} {transport.Model} ({transport.Year})");
        }

        Console.WriteLine("\n=== Обновление значения ===\n");

        string updateKey = "BMW202";
        if (transportDictionary.ContainsKey(updateKey))
        {
            transportDictionary[updateKey] = new Car("X7", "BMW", 2024, 95000m, 4, "Дизель", true);
            Console.WriteLine($"Транспорт с номером {updateKey} обновлен:");
            transportDictionary[updateKey].DisplayInfo();
        }

        Console.WriteLine("\n=== Комбинированное использование List и Dictionary ===\n");

        Dictionary<string, List<Transport>> transportByManufacturer = new Dictionary<string, List<Transport>>();

        foreach (var kvp in transportDictionary)
        {
            string manufacturer = kvp.Value.Manufacturer;
            
            if (!transportByManufacturer.ContainsKey(manufacturer))
            {
                transportByManufacturer[manufacturer] = new List<Transport>();
            }
            
            transportByManufacturer[manufacturer].Add(kvp.Value);
        }

        Console.WriteLine("Транспорт сгруппирован по производителям:");
        foreach (var kvp in transportByManufacturer)
        {
            Console.WriteLine($"\n{kvp.Key}:");
            foreach (var transport in kvp.Value)
            {
                Console.WriteLine($"  - {transport.Model} ({transport.Year})");
            }
        }

        Console.WriteLine("\n=== LINQ запросы к коллекциям ===\n");

        var carsOnly = transportList.OfType<Car>().ToList();
        Console.WriteLine($"Количество автомобилей: {carsOnly.Count}");

        var bikesOnly = transportList.OfType<Bike>().ToList();
        Console.WriteLine($"Количество велосипедов: {bikesOnly.Count}");

        var averagePrice = transportList.Average(t => t.Price);
        Console.WriteLine($"\nСредняя цена транспорта: {averagePrice:C}");

        var mostExpensive = transportList.OrderByDescending(t => t.Price).First();
        Console.WriteLine($"\nСамый дорогой транспорт:");
        mostExpensive.DisplayInfo();

        var recentTransport = transportList.Where(t => t.Year >= 2023).ToList();
        Console.WriteLine($"\nТранспорт 2023 года и новее: {recentTransport.Count} единиц");
        foreach (var transport in recentTransport)
        {
            Console.WriteLine($"- {transport.Manufacturer} {transport.Model}");
        }

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (3-4 например Dog, Cat, Bird и так далее) реализуйте при помощи  List<T> и  Dictionary<TKey,TValue>.

// %%
using System;
using System.Collections.Generic;
using System.Linq;

public class Animal
{
    public string Name { get; set; }
    public int Age { get; set; }
    public double Weight { get; set; }
    public string Habitat { get; set; }

    public Animal(string name, int age, double weight, string habitat)
    {
        Name = name;
        Age = age;
        Weight = weight;
        Habitat = habitat;
    }

    public virtual void DisplayInfo()
    {
        Console.WriteLine($"Имя: {Name}, Возраст: {Age} лет, Вес: {Weight}кг, Среда обитания: {Habitat}");
    }

    public virtual void MakeSound()
    {
        Console.WriteLine($"{Name} издает звук");
    }

    public virtual void Move()
    {
        Console.WriteLine($"{Name} перемещается");
    }
}

public class Dog : Animal
{
    public string Breed { get; set; }
    public bool IsTrained { get; set; }
    public string FavoriteToy { get; set; }

    public Dog(string name, int age, double weight, string habitat, string breed, bool isTrained, string favoriteToy)
        : base(name, age, weight, habitat)
    {
        Breed = breed;
        IsTrained = isTrained;
        FavoriteToy = favoriteToy;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Порода: {Breed}, Дрессирован: {(IsTrained ? "Да" : "Нет")}, Любимая игрушка: {FavoriteToy}");
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} лает: Гав-гав!");
    }

    public override void Move()
    {
        Console.WriteLine($"{Name} бегает по земле");
    }

    public void Fetch()
    {
        Console.WriteLine($"{Name} приносит {FavoriteToy}");
    }
}

public class Cat : Animal
{
    public string Color { get; set; }
    public bool IsIndoor { get; set; }
    public int Lives { get; set; }

    public Cat(string name, int age, double weight, string habitat, string color, bool isIndoor, int lives)
        : base(name, age, weight, habitat)
    {
        Color = color;
        IsIndoor = isIndoor;
        Lives = lives;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Цвет: {Color}, Домашний: {(IsIndoor ? "Да" : "Нет")}, Жизней: {Lives}");
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} мяукает: Мяу-мяу!");
    }

    public override void Move()
    {
        Console.WriteLine($"{Name} грациозно ходит");
    }

    public void Purr()
    {
        Console.WriteLine($"{Name} мурлычет: Мрррр...");
    }
}

public class Bird : Animal
{
    public double Wingspan { get; set; }
    public bool CanFly { get; set; }
    public string BeakType { get; set; }

    public Bird(string name, int age, double weight, string habitat, double wingspan, bool canFly, string beakType)
        : base(name, age, weight, habitat)
    {
        Wingspan = wingspan;
        CanFly = canFly;
        BeakType = beakType;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Размах крыльев: {Wingspan}см, Умеет летать: {(CanFly ? "Да" : "Нет")}, Тип клюва: {BeakType}");
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} чирикает: Чик-чирик!");
    }

    public override void Move()
    {
        if (CanFly)
            Console.WriteLine($"{Name} летит в небе");
        else
            Console.WriteLine($"{Name} прыгает по земле");
    }

    public void BuildNest()
    {
        Console.WriteLine($"{Name} строит гнездо");
    }
}

public class Fish : Animal
{
    public string WaterType { get; set; }
    public bool HasScales { get; set; }
    public int FinCount { get; set; }

    public Fish(string name, int age, double weight, string habitat, string waterType, bool hasScales, int finCount)
        : base(name, age, weight, habitat)
    {
        WaterType = waterType;
        HasScales = hasScales;
        FinCount = finCount;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Тип воды: {WaterType}, Чешуя: {(HasScales ? "Есть" : "Нет")}, Плавников: {FinCount}");
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} издает звуки: Буль-буль...");
    }

    public override void Move()
    {
        Console.WriteLine($"{Name} плавает в воде");
    }

    public void Swim()
    {
        Console.WriteLine($"{Name} быстро плавает, используя {FinCount} плавников");
    }
}

Console.WriteLine("=== Работа с List<Animal> ===\n");

List<Animal> animalList = new List<Animal>();

animalList.Add(new Dog("Барсик", 3, 12.5, "Дом", "Лабрадор", true, "Мячик"));
animalList.Add(new Dog("Рекс", 5, 25.0, "Дом", "Овчарка", true, "Кость"));
animalList.Add(new Cat("Мурка", 2, 4.2, "Дом", "Серый", true, 9));
animalList.Add(new Cat("Васька", 4, 5.1, "Улица", "Рыжий", false, 7));
animalList.Add(new Bird("Кеша", 1, 0.3, "Лес", 15.5, true, "Короткий"));
animalList.Add(new Bird("Гоша", 2, 1.2, "Дом", 0, false, "Крючковатый"));
animalList.Add(new Fish("Немо", 1, 0.2, "Океан", "Соленая", true, 5));
animalList.Add(new Fish("Золотик", 2, 0.1, "Аквариум", "Пресная", true, 5));

Console.WriteLine("Все животные в списке:");
foreach (var animal in animalList)
{
    animal.DisplayInfo();
    Console.WriteLine();
}

Console.WriteLine("\n=== Операции со списком ===\n");

Console.WriteLine($"Общее количество животных: {animalList.Count}");

animalList.RemoveAt(1);
Console.WriteLine($"После удаления элемента по индексу 1: {animalList.Count} элементов");

Animal firstAnimal = animalList[0];
Console.WriteLine("\nПервый элемент списка:");
firstAnimal.DisplayInfo();

Console.WriteLine("\n--- Только собаки ---");
foreach (var animal in animalList)
{
    if (animal is Dog dog)
    {
        dog.DisplayInfo();
        dog.Fetch();
        Console.WriteLine();
    }
}

Console.WriteLine("--- Только кошки ---");
foreach (var animal in animalList)
{
    if (animal is Cat cat)
    {
        cat.DisplayInfo();
        cat.Purr();
        Console.WriteLine();
    }
}

Console.WriteLine("--- Только птицы ---");
foreach (var animal in animalList)
{
    if (animal is Bird bird)
    {
        bird.DisplayInfo();
        bird.BuildNest();
        Console.WriteLine();
    }
}

Console.WriteLine("--- Только рыбы ---");
foreach (var animal in animalList)
{
    if (animal is Fish fish)
    {
        fish.DisplayInfo();
        fish.Swim();
        Console.WriteLine();
    }
}

List<Animal> heavyAnimals = animalList.FindAll(a => a.Weight > 5);
Console.WriteLine($"\nЖивотные тяжелее 5кг: {heavyAnimals.Count} особей");
foreach (var animal in heavyAnimals)
{
    Console.WriteLine($"- {animal.Name}: {animal.Weight}кг");
}

animalList.Sort((a1, a2) => a1.Age.CompareTo(a2.Age));
Console.WriteLine("\nСписок отсортирован по возрасту (по возрастанию):");
foreach (var animal in animalList)
{
    Console.WriteLine($"{animal.Name}: {animal.Age} лет");
}

Console.WriteLine("\n\n=== Работа с Dictionary<string, Animal> ===\n");

Dictionary<string, Animal> animalDictionary = new Dictionary<string, Animal>();

animalDictionary.Add("D001", new Dog("Бобик", 4, 18.0, "Дом", "Дворняжка", false, "Веревка"));
animalDictionary.Add("D002", new Dog("Шарик", 2, 8.5, "Дом", "Такса", true, "Мягкая игрушка"));
animalDictionary.Add("C001", new Cat("Снежок", 1, 3.8, "Дом", "Белый", true, 9));
animalDictionary.Add("C002", new Cat("Рыжик", 3, 4.5, "Улица", "Рыжий", false, 8));
animalDictionary.Add("B001", new Bird("Соловей", 2, 0.2, "Лес", 12.0, true, "Тонкий"));
animalDictionary.Add("B002", new Bird("Попугай", 5, 0.4, "Дом", 20.0, true, "Крючковатый"));
animalDictionary.Add("F001", new Fish("Дори", 1, 0.15, "Океан", "Соленая", true, 5));
animalDictionary.Add("F002", new Fish("Пузырек", 2, 0.08, "Аквариум", "Пресная", true, 5));

Console.WriteLine("Все животные в словаре:");
foreach (var kvp in animalDictionary)
{
    Console.WriteLine($"\nID: {kvp.Key}");
    kvp.Value.DisplayInfo();
}

Console.WriteLine("\n\n=== Поиск по ключу ===\n");

string searchKey = "D001";
if (animalDictionary.TryGetValue(searchKey, out Animal foundAnimal))
{
    Console.WriteLine($"Найдено животное с ID {searchKey}:");
    foundAnimal.DisplayInfo();
    foundAnimal.MakeSound();
    foundAnimal.Move();
}
else
{
    Console.WriteLine("Животное не найдено");
}

Console.WriteLine("\n=== Проверка наличия ключа ===\n");

string checkKey = "C001";
if (animalDictionary.ContainsKey(checkKey))
{
    Console.WriteLine($"Животное с ID {checkKey} существует");
    Console.WriteLine($"Это: {animalDictionary[checkKey].Name}");
}

Console.WriteLine("\n=== Удаление элемента ===\n");

string removeKey = "F002";
if (animalDictionary.Remove(removeKey))
{
    Console.WriteLine($"Животное с ID {removeKey} успешно удалено");
    Console.WriteLine($"Осталось элементов в словаре: {animalDictionary.Count}");
}

Console.WriteLine("\n=== Получение всех ключей ===\n");

Console.WriteLine("Все ID животных:");
foreach (var key in animalDictionary.Keys)
{
    Console.WriteLine($"- {key}");
}

Console.WriteLine("\n=== Получение всех значений ===\n");

Console.WriteLine("Все животные:");
foreach (var animal in animalDictionary.Values)
{
    Console.WriteLine($"- {animal.Name} ({animal.GetType().Name})");
}

Console.WriteLine("\n=== Обновление значения ===\n");

string updateKey = "B001";
if (animalDictionary.ContainsKey(updateKey))
{
    animalDictionary[updateKey] = new Bird("Сокол", 3, 0.6, "Горы", 35.0, true, "Острый");
    Console.WriteLine($"Животное с ID {updateKey} обновлено:");
    animalDictionary[updateKey].DisplayInfo();
}

Console.WriteLine("\n=== Комбинированное использование List и Dictionary ===\n");

Dictionary<string, List<Animal>> animalsByHabitat = new Dictionary<string, List<Animal>>();

foreach (var kvp in animalDictionary)
{
    string habitat = kvp.Value.Habitat;
    
    if (!animalsByHabitat.ContainsKey(habitat))
    {
        animalsByHabitat[habitat] = new List<Animal>();
    }
    
    animalsByHabitat[habitat].Add(kvp.Value);
}

Console.WriteLine("Животные сгруппированы по среде обитания:");
foreach (var kvp in animalsByHabitat)
{
    Console.WriteLine($"\n{kvp.Key}:");
    foreach (var animal in kvp.Value)
    {
        Console.WriteLine($"  - {animal.Name} ({animal.GetType().Name})");
    }
}

Console.WriteLine("\n=== LINQ запросы к коллекциям ===\n");

var dogsOnly = animalList.OfType<Dog>().ToList();
Console.WriteLine($"Количество собак: {dogsOnly.Count}");

var catsOnly = animalList.OfType<Cat>().ToList();
Console.WriteLine($"Количество кошек: {catsOnly.Count}");

var birdsOnly = animalList.OfType<Bird>().ToList();
Console.WriteLine($"Количество птиц: {birdsOnly.Count}");

var fishOnly = animalList.OfType<Fish>().ToList();
Console.WriteLine($"Количество рыб: {fishOnly.Count}");

var averageWeight = animalList.Average(a => a.Weight);
Console.WriteLine($"\nСредний вес животных: {averageWeight:F2}кг");

var oldestAnimal = animalList.OrderByDescending(a => a.Age).First();
Console.WriteLine($"\nСамое старое животное:");
oldestAnimal.DisplayInfo();

var youngAnimals = animalList.Where(a => a.Age < 3).ToList();
Console.WriteLine($"\nМолодые животные (до 3 лет): {youngAnimals.Count} особей");
foreach (var animal in youngAnimals)
{
    Console.WriteLine($"- {animal.Name}: {animal.Age} лет");
}

var domesticAnimals = animalList.Where(a => a.Habitat == "Дом").ToList();
Console.WriteLine($"\nДомашние животные: {domesticAnimals.Count} особей");
foreach (var animal in domesticAnimals)
{
    Console.WriteLine($"- {animal.Name}");
}

Console.WriteLine("\n=== Демонстрация полиморфизма ===\n");

foreach (var animal in animalList)
{
    animal.MakeSound();
    animal.Move();
    Console.WriteLine();
}
// Out:
// === Работа с List<Animal> ===
//
// Все животные в списке:
// Имя: Барсик, Возраст: 3 лет, Вес: 12,5кг, Среда обитания: Дом
// Порода: Лабрадор, Дрессирован: Да, Любимая игрушка: Мячик
//
// Имя: Рекс, Возраст: 5 лет, Вес: 25кг, Среда обитания: Дом
// Порода: Овчарка, Дрессирован: Да, Любимая игрушка: Кость
//
// Имя: Мурка, Возраст: 2 лет, Вес: 4,2кг, Среда обитания: Дом
// Цвет: Серый, Домашний: Да, Жизней: 9
//
// Имя: Васька, Возраст: 4 лет, Вес: 5,1кг, Среда обитания: Улица
// Цвет: Рыжий, Домашний: Нет, Жизней: 7
//
// Имя: Кеша, Возраст: 1 лет, Вес: 0,3кг, Среда обитания: Лес
// Размах крыльев: 15,5см, Умеет летать: Да, Тип клюва: Короткий
//
// Имя: Гоша, Возраст: 2 лет, Вес: 1,2кг, Среда обитания: Дом
// Размах крыльев: 0см, Умеет летать: Нет, Тип клюва: Крючковатый
//
// Имя: Немо, Возраст: 1 лет, Вес: 0,2кг, Среда обитания: Океан
// Тип воды: Соленая, Чешуя: Есть, Плавников: 5
//
// Имя: Золотик, Возраст: 2 лет, Вес: 0,1кг, Среда обитания: Аквариум
// Тип воды: Пресная, Чешуя: Есть, Плавников: 5
//
//
// === Операции со списком ===
//
// Общее количество животных: 8
// После удаления элемента по индексу 1: 7 элементов
//
// Первый элемент списка:
// Имя: Барсик, Возраст: 3 лет, Вес: 12,5кг, Среда обитания: Дом
// Порода: Лабрадор, Дрессирован: Да, Любимая игрушка: Мячик
//
// --- Только собаки ---
// Имя: Барсик, Возраст: 3 лет, Вес: 12,5кг, Среда обитания: Дом
// Порода: Лабрадор, Дрессирован: Да, Любимая игрушка: Мячик
// Барсик приносит Мячик
//
// --- Только кошки ---
// Имя: Мурка, Возраст: 2 лет, Вес: 4,2кг, Среда обитания: Дом
// Цвет: Серый, Домашний: Да, Жизней: 9
// Мурка мурлычет: Мрррр...
//
// Имя: Васька, Возраст: 4 лет, Вес: 5,1кг, Среда обитания: Улица
// Цвет: Рыжий, Домашний: Нет, Жизней: 7
// Васька мурлычет: Мрррр...
//
// --- Только птицы ---
// Имя: Кеша, Возраст: 1 лет, Вес: 0,3кг, Среда обитания: Лес
// Размах крыльев: 15,5см, Умеет летать: Да, Тип клюва: Короткий
// Кеша строит гнездо
//
// Имя: Гоша, Возраст: 2 лет, Вес: 1,2кг, Среда обитания: Дом
// Размах крыльев: 0см, Умеет летать: Нет, Тип клюва: Крючковатый
// Гоша строит гнездо
//
// --- Только рыбы ---
// Имя: Немо, Возраст: 1 лет, Вес: 0,2кг, Среда обитания: Океан
// Тип воды: Соленая, Чешуя: Есть, Плавников: 5
// Немо быстро плавает, используя 5 плавников
//
// Имя: Золотик, Возраст: 2 лет, Вес: 0,1кг, Среда обитания: Аквариум
// Тип воды: Пресная, Чешуя: Есть, Плавников: 5
// Золотик быстро плавает, используя 5 плавников
//
//
// Животные тяжелее 5кг: 2 особей
// - Барсик: 12,5кг
// - Васька: 5,1кг
//
// Список отсортирован по возрасту (по возрастанию):
// Кеша: 1 лет
// Немо: 1 лет
// Мурка: 2 лет
// Гоша: 2 лет
// Золотик: 2 лет
// Барсик: 3 лет
// Васька: 4 лет
//
//
// === Работа с Dictionary<string, Animal> ===
//
// Все животные в словаре:
//
// ID: D001
// Имя: Бобик, Возраст: 4 лет, Вес: 18кг, Среда обитания: Дом
// Порода: Дворняжка, Дрессирован: Нет, Любимая игрушка: Веревка
//
// ID: D002
// Имя: Шарик, Возраст: 2 лет, Вес: 8,5кг, Среда обитания: Дом
// Порода: Такса, Дрессирован: Да, Любимая игрушка: Мягкая игрушка
//
// ID: C001
// Имя: Снежок, Возраст: 1 лет, Вес: 3,8кг, Среда обитания: Дом
// Цвет: Белый, Домашний: Да, Жизней: 9
//
// ID: C002
// Имя: Рыжик, Возраст: 3 лет, Вес: 4,5кг, Среда обитания: Улица
// Цвет: Рыжий, Домашний: Нет, Жизней: 8
//
// ID: B001
// Имя: Соловей, Возраст: 2 лет, Вес: 0,2кг, Среда обитания: Лес
// Размах крыльев: 12см, Умеет летать: Да, Тип клюва: Тонкий
//
// ID: B002
// Имя: Попугай, Возраст: 5 лет, Вес: 0,4кг, Среда обитания: Дом
// Размах крыльев: 20см, Умеет летать: Да, Тип клюва: Крючковатый
//
// ID: F001
// Имя: Дори, Возраст: 1 лет, Вес: 0,15кг, Среда обитания: Океан
// Тип воды: Соленая, Чешуя: Есть, Плавников: 5
//
// ID: F002
// Имя: Пузырек, Возраст: 2 лет, Вес: 0,08кг, Среда обитания: Аквариум
// Тип воды: Пресная, Чешуя: Есть, Плавников: 5
//
//
// === Поиск по ключу ===
//
// Найдено животное с ID D001:
// Имя: Бобик, Возраст: 4 лет, Вес: 18кг, Среда обитания: Дом
// Порода: Дворняжка, Дрессирован: Нет, Любимая игрушка: Веревка
// Бобик лает: Гав-гав!
// Бобик бегает по земле
//
// === Проверка наличия ключа ===
//
// Животное с ID C001 существует
// Это: Снежок
//
// === Удаление элемента ===
//
// Животное с ID F002 успешно удалено
// Осталось элементов в словаре: 7
//
// === Получение всех ключей ===
//
// Все ID животных:
// - D001
// - D002
// - C001
// - C002
// - B001
// - B002
// - F001
//
// === Получение всех значений ===
//
// Все животные:
// - Бобик (Dog)
// - Шарик (Dog)
// - Снежок (Cat)
// - Рыжик (Cat)
// - Соловей (Bird)
// - Попугай (Bird)
// - Дори (Fish)
//
// === Обновление значения ===
//
// Животное с ID B001 обновлено:
// Имя: Сокол, Возраст: 3 лет, Вес: 0,6кг, Среда обитания: Горы
// Размах крыльев: 35см, Умеет летать: Да, Тип клюва: Острый
//
// === Комбинированное использование List и Dictionary ===
//
// Животные сгруппированы по среде обитания:
//
// Дом:
//   - Бобик (Dog)
//   - Шарик (Dog)
//   - Снежок (Cat)
//   - Попугай (Bird)
//
// Улица:
//   - Рыжик (Cat)
//
// Горы:
//   - Сокол (Bird)
//
// Океан:
//   - Дори (Fish)
//
// === LINQ запросы к коллекциям ===
//
// Количество собак: 1
// Количество кошек: 2
// Количество птиц: 2
// Количество рыб: 2
//
// Средний вес животных: 3,37кг
//
// Самое старое животное:
// Имя: Васька, Возраст: 4 лет, Вес: 5,1кг, Среда обитания: Улица
// Цвет: Рыжий, Домашний: Нет, Жизней: 7
//
// Молодые животные (до 3 лет): 5 особей
// - Кеша: 1 лет
// - Немо: 1 лет
// - Мурка: 2 лет
// - Гоша: 2 лет
// - Золотик: 2 лет
//
// Домашние животные: 3 особей
// - Мурка
// - Гоша
// - Барсик
//
// === Демонстрация полиморфизма ===
//
// Кеша чирикает: Чик-чирик!
// Кеша летит в небе
//
// Немо издает звуки: Буль-буль...
// Немо плавает в воде
//
// Мурка мяукает: Мяу-мяу!
// Мурка грациозно ходит
//
// Гоша чирикает: Чик-чирик!
// Гоша прыгает по земле
//
// Золотик издает звуки: Буль-буль...
// Золотик плавает в воде
//
// Барсик лает: Гав-гав!
// Барсик бегает по земле
//
// Васька мяукает: Мяу-мяу!
// Васька грациозно ходит
